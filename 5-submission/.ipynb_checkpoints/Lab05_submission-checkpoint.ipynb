# %% [markdown]
# # Lab 05 Submission
#
# ## Due on the day of your lab session (14-18 February) latest by 8:00 PM
#
# In this activity, you will work with **Income Dataset** from UCI Machine Learning portal. The Adult Income data set has been used in many machine learning papers that address classification problems. You will read the data from a CSV file into a Pandas DataFrame and do practice some of the advanced data wrangling you learned in this Lesson.
#
# ### Attributes/Variables
#
# Following are the details of the type of the attributes of this dataset for your reference. You may have to refer them while answering question on this activity. Note that, many of the attributes are of discrete factor type. These are common type for a classification problem unlike continuous numeric values used for regression problems.
#
# * __age__: continuous.
# * __workclass__: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * __fnlwgt__: continuous.
# * __education__: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * __education-num__: continuous.
# * __marital-status__: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * __occupation__: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * __relationship__: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * __race__: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * __sex__: Female, Male.
# * __capital-gain__: continuous.
# * __capital-loss__: continuous.
# * __hours-per-week__: continuous.
# * __native-country__: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
#
# ### A special note on the variable 'fnlwgt':
#
# The weights on the CPS files are controlled to independent estimates of the civilian noninstitutional population of the US.  These are prepared monthly for us by Population Division here at the Census Bureau.  We use 3 sets of controls. These are:
# 1.  A single cell estimate of the population 16+ for each state.
# 2.  Controls for Hispanic Origin by age and sex.
# 3.  Controls by Race, age and sex.
#
# We use all three sets of controls in our weighting program and "rake" through them 6 times so that by the end we come back to all the controls we used. The term estimate refers to population totals derived from CPS by creating "weighted tallies" of any specified socio-economic characteristics of the population.
#
# People with similar demographic characteristics should have similar weights. There is one important caveat to remember about this statement.  That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.

# %%
name = "Muhammad Haziq Faiz Bin Mohd Ripin"
sid  = "1201302740"

# %% [markdown]
# ### import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read in the income data set (census.csv) for the current directory

# %%
df = pd.read_csv('census.csv')
df.head()
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# ### Do you think the column names (headers) make sense?

# %% [markdown]
# Yes

# %%
# you can experiment here

# %% [markdown]
# ### Time to read in the text file with data descriptions and extract header names
# Write a file reading script which reads the text file line by line, and extracts the first phrase which is the header name

# %%
with open('names.txt') as f:
    contents = f.readlines()
    
i=0
header=[]
while(i<len(contents)):
    test = contents[i].split()[0]
    test = test.replace(":","")
    i=i+2
    header.append(test)

# %% [markdown]
# ### Add a name ("_Income_") for the response variable (last column) to the dataset and read it again with the column names supplied

# %%
if "income" not in header:
    header.append("income")
print(header)
len(header)
# Out:
# ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
# 14

# %%
header
df = pd.read_csv('census.csv',skipinitialspace = True)
#df.set_index('',inplace=True)

df.head()
# Out:
#    age         workclass  final-weight  education  education-num  \
# 0   39         State-gov         77516  Bachelors             13
# 1   50  Self-emp-not-inc         83311  Bachelors             13
# 2   38           Private        215646    HS-grad              9
# 3   53           Private        234721       11th              7
# 4   28           Private        338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loos  hour-per-week native-country income
# 0          2174             0             40  United-States  <=50K
# ...

# %% [markdown]
# ### Show a statistical summary of the data set. Did you notice only a small number of columns are included?

# %%
df.describe()
# Out:
#                 age  final-weight  education-num  capital-gain  capital-loos  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hour-per-week
# count   32561.000000
# mean       40.437456
# std        12.347429
# min         1.000000
# 25%        40.000000
# 50%        40.000000
# 75%        45.000000
# max        99.000000

# %% [markdown]
# ### Many variables in the dataset have classes (Categorical).
# 1. Create a list of these variable names.
# 2. Can you write a loop to count, list these classes and print them?
#
# *Use unique() and nunique() functions

# %%
#get a list of categorical variables
i=0
uniqueheader=[]
while(i<len(contents)):
    first = contents[i].split()[0]
    first = first.replace(":","")
    second = contents[i].split()[1]
    second = second.replace(".","")
    i=i+2
    if(second!="continuous"):
        uniqueheader.append(first)

uniqueheader
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'sex',
#  'native-country']

# %%
# get the categories from the list of categorical variables
for i in uniqueheader:
    categories=df[i].unique()
    for j in categories:
        print(f"For column {i},category {j} has {len(df[df[i]==j])}")
    print()
# Out:
# For column workclass,category State-gov has 1298
# For column workclass,category Self-emp-not-inc has 2541
# For column workclass,category Private has 22696
# For column workclass,category Federal-gov has 960
# For column workclass,category Local-gov has 2093
# For column workclass,category ? has 1836
# For column workclass,category Self-emp-inc has 1116
# For column workclass,category Without-pay has 14
# For column workclass,category Never-worked has 7
#
# For column education,category Bachelors has 5355
# For column education,category HS-grad has 10501
# For column education,category 11th has 1175
# For column education,category Masters has 1723
# For column education,category 9th has 514
# For column education,category Some-college has 7291
# For column education,category Assoc-acdm has 1067
# For column education,category Assoc-voc has 1382
# For column education,category 7th-8th has 646
# For column education,category Doctorate has 413
# ...

# %% [markdown]
# ### Is there any missing (NULL) data in the dataset? Write a single line of code to show this for all coumns

# %%
df[df.isnull()]
# Out:
#        age workclass  final-weight education  education-num marital-status  \
# 0      NaN       NaN           NaN       NaN            NaN            NaN
# 1      NaN       NaN           NaN       NaN            NaN            NaN
# 2      NaN       NaN           NaN       NaN            NaN            NaN
# 3      NaN       NaN           NaN       NaN            NaN            NaN
# 4      NaN       NaN           NaN       NaN            NaN            NaN
# ...    ...       ...           ...       ...            ...            ...
# 32556  NaN       NaN           NaN       NaN            NaN            NaN
# 32557  NaN       NaN           NaN       NaN            NaN            NaN
# 32558  NaN       NaN           NaN       NaN            NaN            NaN
# 32559  NaN       NaN           NaN       NaN            NaN            NaN
# 32560  NaN       NaN           NaN       NaN            NaN            NaN
#
# ...

# %% [markdown]
# ### Practice subsetting: Create a DataFrame with only
# * age,
# * education,
# * occupation
# * race

# %%
# Write your code here
df2 = df[["age","education","occupation","race"]]
df2
# Out:
#        age   education         occupation   race
# 0       39   Bachelors       Adm-clerical  White
# 1       50   Bachelors    Exec-managerial  White
# 2       38     HS-grad  Handlers-cleaners  White
# 3       53        11th  Handlers-cleaners  Black
# 4       28   Bachelors     Prof-specialty  Black
# ...    ...         ...                ...    ...
# 32556   27  Assoc-acdm       Tech-support  White
# 32557   40     HS-grad  Machine-op-inspct  White
# 32558   58     HS-grad       Adm-clerical  White
# 32559   22     HS-grad       Adm-clerical  White
# 32560   52     HS-grad    Exec-managerial  White
#
# [32561 rows x 4 columns]

# %% [markdown]
# ### Show the histogram of age with bin size = 20

# %%
bins=[0,20,40,60,80,100]
df3 = pd.cut(df.age,bins)

df3.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### During reading the dataset from the CSV file, all the strings came with a whitespace character in front. So, we need to remove that whitespace from all the strings.

# %% [markdown]
# ### write a function that receives a string parameter and strips it from leading spaces.

# %%
#I already did this when I opened the csv with skipinitialspace = True
def fun(x):
    return x.strip()

# %% [markdown]
# ### Use the 'apply' method to apply this function to all the columns with string values, create a new column, copy the values from this new column to the old column, and drop the new column.
#
# #### This is the preferred method so that you don't accidentally delete valuable data. Most of the time, create a new column with a desired operation and then copy it back to the old column if necessary.

# %%
#make a copy because I dont want to ruin the original dataframe
df_copy = df.copy()

#Get a list of column whose datatype is object
l=[]
for column in df_copy:
    if df_copy[column].dtypes == "object":
        l.append(column)
#create a new column for each of the original column whose dataype is object
new_l=[]
for i in l:
    newName = "new"+i
    new_l.append(newName)
    df_copy[newName] = df[i]
    df_copy[newName].apply(fun)

#drop the new columns
for i in new_l:
    #print(df_copy[i])
    df_copy=df_copy.drop([i],axis=1)
    
df=df_copy
del df_copy
df
# Out:
#        age         workclass  final-weight   education  education-num  \
# 0       39         State-gov         77516   Bachelors             13
# 1       50  Self-emp-not-inc         83311   Bachelors             13
# 2       38           Private        215646     HS-grad              9
# 3       53           Private        234721        11th              7
# 4       28           Private        338409   Bachelors             13
# ...    ...               ...           ...         ...            ...
# 32556   27           Private        257302  Assoc-acdm             12
# 32557   40           Private        154374     HS-grad              9
# 32558   58           Private        151910     HS-grad              9
# 32559   22           Private        201490     HS-grad              9
# 32560   52      Self-emp-inc        287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# ...

# %% [markdown]
# ### Answer the following question using conditional filtering/boolean indexing: <br><br> _"How many male of age between 30 and 50 (inclusive) are represented in this dataset?"_

# %%
# Write a code with conditional clauses and join them by & (AND) to filter the dataframe
df4 = df[(df["sex"]=="Male") & (df["age"]>=30) & (df["age"]<=50)]

# %%
# We can look at the shape of the filtered dataframe and take the 1st element at 0 index of the tuple
df4.shape[0]
# Out:
# 11497

# %%
# Print out the number of males between 30 and 50
len(df4)
# Out:
# 11497

# %% [markdown]
# ### Practice "GroupBy": Group by race and education to show how the mean age is distributed

# %%
# Write your code here
df5 = df.groupby(["race","education"]).mean().age
df5
# Out:
# race                education
# Amer-Indian-Eskimo  10th            37.250000
#                     11th            31.642857
#                     12th            25.400000
#                     1st-4th         45.750000
#                     5th-6th         39.000000
#                                       ...
# White               HS-grad         39.270777
#                     Masters         44.338972
#                     Preschool       40.289474
#                     Prof-school     44.996109
#                     Some-college    35.980989
# Name: age, Length: 79, dtype: float64

# %% [markdown]
# ### Group by occupation and show the summary statistics of age. Try to answer the following questions,
# * Which profession has oldest workers on the average?
# * Which profession has its largest share of workforce above 75th percentile?

# %%
# Write your code here to answer the questions above
df6 = df.groupby(["occupation"]).mean().sort_values("age",ascending=False)
df6[df6.age==df6.age.max()]
# Out:
#                        age   final-weight  education-num  capital-gain  \
# occupation
# Exec-managerial  42.169208  184414.012543       11.44909   2262.772996
#
#                  capital-loos  hour-per-week
# occupation
# Exec-managerial    138.838416      44.987703

# %%
q75 = df["age"].quantile(.75)
#get the 75th percentile which is 48.0
q75

df7 = df[df.age>q75]
df7 = df7.groupby(["occupation"]).count().sort_values("age",ascending=False)
df7[df7.age==df7.age.max()]
# Out:
#                   age  workclass  final-weight  education  education-num  \
# occupation
# Exec-managerial  1165       1165          1165       1165           1165
#
#                  marital-status  relationship  race   sex  capital-gain  \
# occupation
# Exec-managerial            1165          1165  1165  1165          1165
#
#                  capital-loos  hour-per-week  native-country  income
# occupation
# Exec-managerial          1165           1165            1165    1165
